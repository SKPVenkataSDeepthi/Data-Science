# %% [markdown]
# # Loading a CSV file into a dataframe
# * CSV files are the Comma Separated Files. It allows users to load tabular data into a DataFrame, which is a powerful structure for data manipulation and analysis. To access data from the CSV file, we require a function read_csv() from Pandas that retrieves data in the form of the data frame.

# %%
import pandas as pd

df = pd.read_csv("Airline Dataset Updated - v2.csv")
df
# Out:
#       Passenger ID  First Name  Last Name  Gender  Age Nationality  \
# 0           ABVWIg      Edithe     Leggis  Female   62       Japan
# 1           jkXXAX      Elwood       Catt    Male   62   Nicaragua
# 2           CdUz2g       Darby    Felgate    Male   67      Russia
# 3           BRS38V    Dominica       Pyle  Female   71       China
# 4           9kvTLo         Bay    Pencost    Male   21       China
# ...            ...         ...        ...     ...  ...         ...
# 98614       hnGQ62      Gareth    Mugford    Male   85       China
# 98615       2omEzh       Kasey   Benedict  Female   19      Russia
# 98616       VUPiVG      Darrin     Lucken    Male   65   Indonesia
# 98617       E47NtS       Gayle  Lievesley  Female   34       China
# 98618       8JYEcz  Wilhelmine     Touret  Female   10      Poland
#
#                       Airport Name Airport Country Code        Country Name  \
# 0                 Coldfoot Airport                   US       United States
# 1                Kugluktuk Airport                   CA              Canada
# 2           Grenoble-Isère Airport                   FR              France
# 3        Ottawa / Gatineau Airport                   CA              Canada
# 4                  Gillespie Field                   US       United States
# ...                            ...                  ...                 ...
# 98614               Hasvik Airport                   NO              Norway
# 98615          Ampampamena Airport                   MG          Madagascar
# 98616  Albacete-Los Llanos Airport                   ES               Spain
# 98617               Gagnoa Airport                   CI       Côte d'Ivoire
# 98618          Yoshkar-Ola Airport                   RU  Russian Federation
#
#       Airport Continent     Continents Departure Date Arrival Airport  \
# 0                   NAM  North America      6/28/2022             CXF
# 1                   NAM  North America     12/26/2022             YCO
# 2                    EU         Europe      1/18/2022             GNB
# 3                   NAM  North America      9/16/2022             YND
# 4                   NAM  North America      2/25/2022             SEE
# ...                 ...            ...            ...             ...
# 98614                EU         Europe     12-11-2022             HAA
# 98615                AF         Africa     10/30/2022             IVA
# 98616                EU         Europe     09-10-2022             ABC
# 98617                AF         Africa     10/26/2022             GGN
# 98618                EU         Europe      4/16/2022             JOK
#
#                 Pilot Name Flight Status
# 0      Fransisco Hazeldine       On Time
# 1          Marla Parsonage       On Time
# 2             Rhonda Amber       On Time
# 3           Kacie Commucci       Delayed
# 4              Ebonee Tree       On Time
# ...                    ...           ...
# 98614     Pammie Kingscote     Cancelled
# 98615       Dorice Lochran     Cancelled
# 98616         Gearalt Main       On Time
# 98617         Judon Chasle     Cancelled
# 98618      Auguste Tindley       Delayed
#
# [98619 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['Passenger ID', 'First Name', 'Last Name', 'Gender', 'Age',
#        'Nationality', 'Airport Name', 'Airport Country Code', 'Country Name',
#        'Airport Continent', 'Continents', 'Departure Date', 'Arrival Airport',
#        'Pilot Name', 'Flight Status'],
#       dtype='object')

# %%
# Read specific columns using read_csv

df = pd.read_csv("Airline Dataset Updated - v2.csv", usecols = ["Passenger ID", "Airport Name", "Arrival Airport"])
df
# Out:
#       Passenger ID                 Airport Name Arrival Airport
# 0           ABVWIg             Coldfoot Airport             CXF
# 1           jkXXAX            Kugluktuk Airport             YCO
# 2           CdUz2g       Grenoble-Isère Airport             GNB
# 3           BRS38V    Ottawa / Gatineau Airport             YND
# 4           9kvTLo              Gillespie Field             SEE
# ...            ...                          ...             ...
# 98614       hnGQ62               Hasvik Airport             HAA
# 98615       2omEzh          Ampampamena Airport             IVA
# 98616       VUPiVG  Albacete-Los Llanos Airport             ABC
# 98617       E47NtS               Gagnoa Airport             GGN
# 98618       8JYEcz          Yoshkar-Ola Airport             JOK
#
# [98619 rows x 3 columns]

# %%
## Setting an index column
df = pd.read_csv("Airline Dataset Updated - v2.csv", index_col = "Departure Date")
df
# Out:
#                Passenger ID  First Name  Last Name  Gender  Age Nationality  \
# Departure Date
# 6/28/2022            ABVWIg      Edithe     Leggis  Female   62       Japan
# 12/26/2022           jkXXAX      Elwood       Catt    Male   62   Nicaragua
# 1/18/2022            CdUz2g       Darby    Felgate    Male   67      Russia
# 9/16/2022            BRS38V    Dominica       Pyle  Female   71       China
# 2/25/2022            9kvTLo         Bay    Pencost    Male   21       China
# ...                     ...         ...        ...     ...  ...         ...
# 12-11-2022           hnGQ62      Gareth    Mugford    Male   85       China
# 10/30/2022           2omEzh       Kasey   Benedict  Female   19      Russia
# 09-10-2022           VUPiVG      Darrin     Lucken    Male   65   Indonesia
# 10/26/2022           E47NtS       Gayle  Lievesley  Female   34       China
# 4/16/2022            8JYEcz  Wilhelmine     Touret  Female   10      Poland
#
#                                Airport Name Airport Country Code  \
# Departure Date
# 6/28/2022                  Coldfoot Airport                   US
# 12/26/2022                Kugluktuk Airport                   CA
# 1/18/2022            Grenoble-Isère Airport                   FR
# 9/16/2022         Ottawa / Gatineau Airport                   CA
# 2/25/2022                   Gillespie Field                   US
# ...                                     ...                  ...
# 12-11-2022                   Hasvik Airport                   NO
# 10/30/2022              Ampampamena Airport                   MG
# 09-10-2022      Albacete-Los Llanos Airport                   ES
# 10/26/2022                   Gagnoa Airport                   CI
# 4/16/2022               Yoshkar-Ola Airport                   RU
#
#                       Country Name Airport Continent     Continents  \
# Departure Date
# 6/28/2022            United States               NAM  North America
# 12/26/2022                  Canada               NAM  North America
# 1/18/2022                   France                EU         Europe
# 9/16/2022                   Canada               NAM  North America
# 2/25/2022            United States               NAM  North America
# ...                            ...               ...            ...
# 12-11-2022                  Norway                EU         Europe
# 10/30/2022              Madagascar                AF         Africa
# 09-10-2022                   Spain                EU         Europe
# 10/26/2022           Côte d'Ivoire                AF         Africa
# 4/16/2022       Russian Federation                EU         Europe
#
#                Arrival Airport           Pilot Name Flight Status
# Departure Date
# 6/28/2022                  CXF  Fransisco Hazeldine       On Time
# 12/26/2022                 YCO      Marla Parsonage       On Time
# 1/18/2022                  GNB         Rhonda Amber       On Time
# 9/16/2022                  YND       Kacie Commucci       Delayed
# 2/25/2022                  SEE          Ebonee Tree       On Time
# ...                        ...                  ...           ...
# 12-11-2022                 HAA     Pammie Kingscote     Cancelled
# 10/30/2022                 IVA       Dorice Lochran     Cancelled
# 09-10-2022                 ABC         Gearalt Main       On Time
# 10/26/2022                 GGN         Judon Chasle     Cancelled
# 4/16/2022                  JOK      Auguste Tindley       Delayed
#
# [98619 rows x 14 columns]

# %%
# Handling missing values
df = pd.read_csv("Airline Dataset Updated - v2.csv", na_values=['N/A', 'Unknown'])
df
# Out:
#       Passenger ID  First Name  Last Name  Gender  Age Nationality  \
# 0           ABVWIg      Edithe     Leggis  Female   62       Japan
# 1           jkXXAX      Elwood       Catt    Male   62   Nicaragua
# 2           CdUz2g       Darby    Felgate    Male   67      Russia
# 3           BRS38V    Dominica       Pyle  Female   71       China
# 4           9kvTLo         Bay    Pencost    Male   21       China
# ...            ...         ...        ...     ...  ...         ...
# 98614       hnGQ62      Gareth    Mugford    Male   85       China
# 98615       2omEzh       Kasey   Benedict  Female   19      Russia
# 98616       VUPiVG      Darrin     Lucken    Male   65   Indonesia
# 98617       E47NtS       Gayle  Lievesley  Female   34       China
# 98618       8JYEcz  Wilhelmine     Touret  Female   10      Poland
#
#                       Airport Name Airport Country Code        Country Name  \
# 0                 Coldfoot Airport                   US       United States
# 1                Kugluktuk Airport                   CA              Canada
# 2           Grenoble-Isère Airport                   FR              France
# 3        Ottawa / Gatineau Airport                   CA              Canada
# 4                  Gillespie Field                   US       United States
# ...                            ...                  ...                 ...
# 98614               Hasvik Airport                   NO              Norway
# 98615          Ampampamena Airport                   MG          Madagascar
# 98616  Albacete-Los Llanos Airport                   ES               Spain
# 98617               Gagnoa Airport                   CI       Côte d'Ivoire
# 98618          Yoshkar-Ola Airport                   RU  Russian Federation
#
#       Airport Continent     Continents Departure Date Arrival Airport  \
# 0                   NAM  North America      6/28/2022             CXF
# 1                   NAM  North America     12/26/2022             YCO
# 2                    EU         Europe      1/18/2022             GNB
# 3                   NAM  North America      9/16/2022             YND
# 4                   NAM  North America      2/25/2022             SEE
# ...                 ...            ...            ...             ...
# 98614                EU         Europe     12-11-2022             HAA
# 98615                AF         Africa     10/30/2022             IVA
# 98616                EU         Europe     09-10-2022             ABC
# 98617                AF         Africa     10/26/2022             GGN
# 98618                EU         Europe      4/16/2022             JOK
#
#                 Pilot Name Flight Status
# 0      Fransisco Hazeldine       On Time
# 1          Marla Parsonage       On Time
# 2             Rhonda Amber       On Time
# 3           Kacie Commucci       Delayed
# 4              Ebonee Tree       On Time
# ...                    ...           ...
# 98614     Pammie Kingscote     Cancelled
# 98615       Dorice Lochran     Cancelled
# 98616         Gearalt Main       On Time
# 98617         Judon Chasle     Cancelled
# 98618      Auguste Tindley       Delayed
#
# [98619 rows x 15 columns]

# %%
## Reading csv files with delimiters 

file_path = "Airline Dataset Updated - v2.csv"
# Try reading with different delimiters
try:
    # Read with comma (default delimiter), skipping bad lines
    df_comma = pd.read_csv(file_path, delimiter=',', on_bad_lines='skip')
    print("Data read using comma delimiter:")
    print(df_comma.head())

except pd.errors.EmptyDataError:
    print("Error reading with comma delimiter.")

except pd.errors.ParserError as e:
    print(f"ParserError when using comma delimiter: {e}")

try:
    # Read with tab delimiter, skipping bad lines
    df_tab = pd.read_csv(file_path, delimiter='\t', on_bad_lines='skip')
    print("\nData read using tab delimiter:")
    print(df_tab.head())

except pd.errors.EmptyDataError:
    print("Error reading with tab delimiter.")

except pd.errors.ParserError as e:
    print(f"ParserError when using tab delimiter: {e}")

try:
    # Read with semicolon delimiter, skipping bad lines
    df_semicolon = pd.read_csv(file_path, delimiter=';', on_bad_lines='skip')
    print("\nData read using semicolon delimiter:")
    print(df_semicolon.head())

except pd.errors.EmptyDataError:
    print("Error reading with semicolon delimiter.")

except pd.errors.ParserError as e:
    print(f"ParserError when using semicolon delimiter: {e}")

try:
    # Read with pipe delimiter, skipping bad lines
    df_pipe = pd.read_csv(file_path, delimiter='|', on_bad_lines='skip')
    print("\nData read using pipe delimiter:")
    print(df_pipe.head())

except pd.errors.EmptyDataError:
    print("Error reading with pipe delimiter.")

except pd.errors.ParserError as e:
    print(f"ParserError when using pipe delimiter: {e}")

try:
    # Read with space delimiter, skipping bad lines
    df_space = pd.read_csv(file_path, delimiter='\s+', on_bad_lines='skip')
    print("\nData read using space delimiter:")
    print(df_space.head())

except pd.errors.EmptyDataError:
    print("Error reading with space delimiter.")

except pd.errors.ParserError as e:
    print(f"ParserError when using space delimiter: {e}")

try:
    # Read with custom delimiter (example: #), skipping bad lines
    df_custom = pd.read_csv(file_path, delimiter='#', on_bad_lines='skip')
    print("\nData read using custom delimiter (#):")
    print(df_custom.head())

except pd.errors.EmptyDataError:
    print("Error reading with custom delimiter (#).")

except pd.errors.ParserError as e:
    print(f"ParserError when using custom delimiter (#): {e}")
# Out:
# <>:55: SyntaxWarning: invalid escape sequence '\s'
# <>:55: SyntaxWarning: invalid escape sequence '\s'
# /var/folders/dp/f1w59vsn4vqbvdmprd4rcvjw0000gn/T/ipykernel_7769/264951600.py:55: SyntaxWarning: invalid escape sequence '\s'
#   df_space = pd.read_csv(file_path, delimiter='\s+', on_bad_lines='skip')
# Data read using comma delimiter:
#   Passenger ID First Name Last Name  Gender  Age Nationality  \
# 0       ABVWIg     Edithe    Leggis  Female   62       Japan
# 1       jkXXAX     Elwood      Catt    Male   62   Nicaragua
# 2       CdUz2g      Darby   Felgate    Male   67      Russia
# 3       BRS38V   Dominica      Pyle  Female   71       China
# 4       9kvTLo        Bay   Pencost    Male   21       China
#
#                 Airport Name Airport Country Code   Country Name  \
# 0           Coldfoot Airport                   US  United States
# 1          Kugluktuk Airport                   CA         Canada
# 2     Grenoble-Isère Airport                   FR         France
# 3  Ottawa / Gatineau Airport                   CA         Canada
# 4            Gillespie Field                   US  United States
#
#   Airport Continent     Continents Departure Date Arrival Airport  \
# 0               NAM  North America      6/28/2022             CXF
# 1               NAM  North America     12/26/2022             YCO
# 2                EU         Europe      1/18/2022             GNB
# 3               NAM  North America      9/16/2022             YND
# 4               NAM  North America      2/25/2022             SEE
#
#             Pilot Name Flight Status
# 0  Fransisco Hazeldine       On Time
# 1      Marla Parsonage       On Time
# 2         Rhonda Amber       On Time
# 3       Kacie Commucci       Delayed
# 4          Ebonee Tree       On Time
#
# Data read using tab delimiter:
#   Passenger ID,First Name,Last Name,Gender,Age,Nationality,Airport Name,Airport Country Code,Country Name,Airport Continent,Continents,Departure Date,Arrival Airport,Pilot Name,Flight Status
# 0  ABVWIg,Edithe,Leggis,Female,62,Japan,Coldfoot ...
# 1  jkXXAX,Elwood,Catt,Male,62,Nicaragua,Kugluktuk...
# 2  CdUz2g,Darby,Felgate,Male,67,Russia,Grenoble-I...
# 3  BRS38V,Dominica,Pyle,Female,71,China,Ottawa / ...
# 4  9kvTLo,Bay,Pencost,Male,21,China,Gillespie Fie...
#
# Data read using semicolon delimiter:
#   Passenger ID,First Name,Last Name,Gender,Age,Nationality,Airport Name,Airport Country Code,Country Name,Airport Continent,Continents,Departure Date,Arrival Airport,Pilot Name,Flight Status
# 0  ABVWIg,Edithe,Leggis,Female,62,Japan,Coldfoot ...
# 1  jkXXAX,Elwood,Catt,Male,62,Nicaragua,Kugluktuk...
# 2  CdUz2g,Darby,Felgate,Male,67,Russia,Grenoble-I...
# 3  BRS38V,Dominica,Pyle,Female,71,China,Ottawa / ...
# 4  9kvTLo,Bay,Pencost,Male,21,China,Gillespie Fie...
#
# Data read using pipe delimiter:
#   Passenger ID,First Name,Last Name,Gender,Age,Nationality,Airport Name,Airport Country Code,Country Name,Airport Continent,Continents,Departure Date,Arrival Airport,Pilot Name,Flight Status
# 0  ABVWIg,Edithe,Leggis,Female,62,Japan,Coldfoot ...
# 1  jkXXAX,Elwood,Catt,Male,62,Nicaragua,Kugluktuk...
# 2  CdUz2g,Darby,Felgate,Male,67,Russia,Grenoble-I...
# 3  BRS38V,Dominica,Pyle,Female,71,China,Ottawa / ...
# 4  9kvTLo,Bay,Pencost,Male,21,China,Gillespie Fie...
#
# Data read using space delimiter:
#                                            Passenger  \
# 0      ABVWIg,Edithe,Leggis,Female,62,Japan,Coldfoot
# 1     jkXXAX,Elwood,Catt,Male,62,Nicaragua,Kugluktuk
# 2  CdUz2g,Darby,Felgate,Male,67,Russia,Grenoble-I...
# 3        BRS38V,Dominica,Pyle,Female,71,China,Ottawa
# 4         9kvTLo,Bay,Pencost,Male,21,China,Gillespie
#
#                                            ID,First  \
# 0                                 Airport,US,United
# 1                       Airport,CA,Canada,NAM,North
# 2  Airport,FR,France,EU,Europe,1/18/2022,GNB,Rhonda
# 3                                                 /
# 4                                   Field,US,United
#
#                       Name,Last Name,Gender,Age,Nationality,Airport  \
# 0              States,NAM,North     America,6/28/2022,CXF,Fransisco
# 1  America,12/26/2022,YCO,Marla                        Parsonage,On
# 2                      Amber,On                                Time
# 3                      Gatineau         Airport,CA,Canada,NAM,North
# 4              States,NAM,North        America,2/25/2022,SEE,Ebonee
#
#                   Name,Airport           Country Code,Country Name,Airport.1  \
# 0                 Hazeldine,On              Time          NaN            NaN
# 1                         Time               NaN          NaN            NaN
# 2                          NaN               NaN          NaN            NaN
# 3  America,9/16/2022,YND,Kacie  Commucci,Delayed          NaN            NaN
# 4                      Tree,On              Time          NaN            NaN
#
#   Continent,Continents,Departure Date,Arrival Airport,Pilot Name,Flight Status
# 0                            NaN          NaN           NaN         NaN    NaN
# 1                            NaN          NaN           NaN         NaN    NaN
# 2                            NaN          NaN           NaN         NaN    NaN
# 3                            NaN          NaN           NaN         NaN    NaN
# 4                            NaN          NaN           NaN         NaN    NaN
#
# Data read using custom delimiter (#):
#   Passenger ID,First Name,Last Name,Gender,Age,Nationality,Airport Name,Airport Country Code,Country Name,Airport Continent,Continents,Departure Date,Arrival Airport,Pilot Name,Flight Status
# 0  ABVWIg,Edithe,Leggis,Female,62,Japan,Coldfoot ...
# 1  jkXXAX,Elwood,Catt,Male,62,Nicaragua,Kugluktuk...
# 2  CdUz2g,Darby,Felgate,Male,67,Russia,Grenoble-I...
# 3  BRS38V,Dominica,Pyle,Female,71,China,Ottawa / ...
# 4  9kvTLo,Bay,Pencost,Male,21,China,Gillespie Fie...

# %%
# Using nrows in read_csv() - The nrows parameter limits the number of rows read from a file, enabling quick previews or partial data loading for large datasets. 

df = pd.read_csv('Airline Dataset Updated - v2.csv', nrows = 3)
df
# Out:
#   Passenger ID First Name Last Name  Gender  Age Nationality  \
# 0       ABVWIg     Edithe    Leggis  Female   62       Japan
# 1       jkXXAX     Elwood      Catt    Male   62   Nicaragua
# 2       CdUz2g      Darby   Felgate    Male   67      Russia
#
#              Airport Name Airport Country Code   Country Name  \
# 0        Coldfoot Airport                   US  United States
# 1       Kugluktuk Airport                   CA         Canada
# 2  Grenoble-Isère Airport                   FR         France
#
#   Airport Continent     Continents Departure Date Arrival Airport  \
# 0               NAM  North America      6/28/2022             CXF
# 1               NAM  North America     12/26/2022             YCO
# 2                EU         Europe      1/18/2022             GNB
#
#             Pilot Name Flight Status
# 0  Fransisco Hazeldine       On Time
# 1      Marla Parsonage       On Time
# 2         Rhonda Amber       On Time

# %%
# using skiprows in read_csv() - The skiprows parameter skips unnecessary rows at the start of a file, which is useful for ignoring metadata or extra headers that are not part of the dataset.

df= pd.read_csv("Airline Dataset Updated - v2.csv")
print("Previous Dataset: ")
print(df)
# using skiprows
df = pd.read_csv("Airline Dataset Updated - v2.csv", skiprows = [4,5])
print("Dataset After skipping rows: ")
print(df)
# Out:
# Previous Dataset:
#       Passenger ID  First Name  Last Name  Gender  Age Nationality  \
# 0           ABVWIg      Edithe     Leggis  Female   62       Japan
# 1           jkXXAX      Elwood       Catt    Male   62   Nicaragua
# 2           CdUz2g       Darby    Felgate    Male   67      Russia
# 3           BRS38V    Dominica       Pyle  Female   71       China
# 4           9kvTLo         Bay    Pencost    Male   21       China
# ...            ...         ...        ...     ...  ...         ...
# 98614       hnGQ62      Gareth    Mugford    Male   85       China
# 98615       2omEzh       Kasey   Benedict  Female   19      Russia
# 98616       VUPiVG      Darrin     Lucken    Male   65   Indonesia
# 98617       E47NtS       Gayle  Lievesley  Female   34       China
# 98618       8JYEcz  Wilhelmine     Touret  Female   10      Poland
#
#                       Airport Name Airport Country Code        Country Name  \
# 0                 Coldfoot Airport                   US       United States
# 1                Kugluktuk Airport                   CA              Canada
# 2           Grenoble-Isère Airport                   FR              France
# 3        Ottawa / Gatineau Airport                   CA              Canada
# 4                  Gillespie Field                   US       United States
# ...                            ...                  ...                 ...
# 98614               Hasvik Airport                   NO              Norway
# 98615          Ampampamena Airport                   MG          Madagascar
# 98616  Albacete-Los Llanos Airport                   ES               Spain
# 98617               Gagnoa Airport                   CI       Côte d'Ivoire
# 98618          Yoshkar-Ola Airport                   RU  Russian Federation
#
#       Airport Continent     Continents Departure Date Arrival Airport  \
# 0                   NAM  North America      6/28/2022             CXF
# 1                   NAM  North America     12/26/2022             YCO
# 2                    EU         Europe      1/18/2022             GNB
# 3                   NAM  North America      9/16/2022             YND
# 4                   NAM  North America      2/25/2022             SEE
# ...                 ...            ...            ...             ...
# 98614                EU         Europe     12-11-2022             HAA
# 98615                AF         Africa     10/30/2022             IVA
# 98616                EU         Europe     09-10-2022             ABC
# 98617                AF         Africa     10/26/2022             GGN
# 98618                EU         Europe      4/16/2022             JOK
#
#                 Pilot Name Flight Status
# 0      Fransisco Hazeldine       On Time
# 1          Marla Parsonage       On Time
# 2             Rhonda Amber       On Time
# 3           Kacie Commucci       Delayed
# 4              Ebonee Tree       On Time
# ...                    ...           ...
# 98614     Pammie Kingscote     Cancelled
# 98615       Dorice Lochran     Cancelled
# 98616         Gearalt Main       On Time
# 98617         Judon Chasle     Cancelled
# 98618      Auguste Tindley       Delayed
#
# [98619 rows x 15 columns]
# Dataset After skipping rows:
#       Passenger ID  First Name  Last Name  Gender  Age  Nationality  \
# 0           ABVWIg      Edithe     Leggis  Female   62        Japan
# 1           jkXXAX      Elwood       Catt    Male   62    Nicaragua
# 2           CdUz2g       Darby    Felgate    Male   67       Russia
# 3           nMJKVh        Lora    Durbann  Female   55       Brazil
# 4           8IPFPE        Rand       Bram    Male   73  Ivory Coast
# ...            ...         ...        ...     ...  ...          ...
# 98612       hnGQ62      Gareth    Mugford    Male   85        China
# 98613       2omEzh       Kasey   Benedict  Female   19       Russia
# 98614       VUPiVG      Darrin     Lucken    Male   65    Indonesia
# 98615       E47NtS       Gayle  Lievesley  Female   34        China
# 98616       8JYEcz  Wilhelmine     Touret  Female   10       Poland
#
#                             Airport Name Airport Country Code  \
# 0                       Coldfoot Airport                   US
# 1                      Kugluktuk Airport                   CA
# 2                 Grenoble-Isère Airport                   FR
# 3      Coronel Horácio de Mattos Airport                   BR
# 4                      Duxford Aerodrome                   GB
# ...                                  ...                  ...
# 98612                     Hasvik Airport                   NO
# 98613                Ampampamena Airport                   MG
# 98614        Albacete-Los Llanos Airport                   ES
# 98615                     Gagnoa Airport                   CI
# 98616                Yoshkar-Ola Airport                   RU
#
#              Country Name Airport Continent     Continents Departure Date  \
# 0           United States               NAM  North America      6/28/2022
# 1                  Canada               NAM  North America     12/26/2022
# 2                  France                EU         Europe      1/18/2022
# 3                  Brazil               SAM  South America     06-10-2022
# 4          United Kingdom                EU         Europe     10/30/2022
# ...                   ...               ...            ...            ...
# 98612              Norway                EU         Europe     12-11-2022
# 98613          Madagascar                AF         Africa     10/30/2022
# 98614               Spain                EU         Europe     09-10-2022
# 98615       Côte d'Ivoire                AF         Africa     10/26/2022
# 98616  Russian Federation                EU         Europe      4/16/2022
#
#       Arrival Airport           Pilot Name Flight Status
# 0                 CXF  Fransisco Hazeldine       On Time
# 1                 YCO      Marla Parsonage       On Time
# 2                 GNB         Rhonda Amber       On Time
# 3                 LEC        Inglis Dolley       On Time
# 4                 QFO     Stanislas Tiffin     Cancelled
# ...               ...                  ...           ...
# 98612             HAA     Pammie Kingscote     Cancelled
# 98613             IVA       Dorice Lochran     Cancelled
# 98614             ABC         Gearalt Main       On Time
# 98615             GGN         Judon Chasle     Cancelled
# 98616             JOK      Auguste Tindley       Delayed
#
# [98617 rows x 15 columns]

# %%
# parse dates - converts date columns into datetime objects, simplyfying operations like filtering, sorting, or time-based analysis.

df = pd.read_csv("Airline Dataset Updated - v2.csv", parse_dates=["Departure Date"])
